# %% [markdown]
# # 튜토리얼 3 - 주가 정보 입수

# %% [markdown]
# 튜토리얼 2에서 CHECK-API 정보를 정상적으로 설정하였다면 본 튜토리얼에서 설명하는 대로 주가 정보를 입수할 수 있습니다.

# %% [markdown]
# ## 3.1 `kquant` 패키지 임포트

# %% [markdown]
# `kquant` 패키지를 임포트 합니다. 본 튜토리얼에서는 `kq`라는 별칭(alias)을 사용합니다.

# %%
import kquant as kq

# %% [markdown]
# ## 3.2 주식 ISIN 코드와 단축코드

# %% [markdown]
# 주식 등 금융상품에 대한 정보를 입수하기 위해서는 종목코드라고 부르는 해당 상품의 코드(code) 혹은 심볼(symbol)정보를 알고 있어야 합니다.
#
# 국내의 금융상품 코드는 공식적으로 12자리 영문자 및 숫자로 구성된 **국제증권식별번호**(ISIN: International Securities Identification Number)를 사용합니다. 예를 들어 삼성전자의 ISIN 코드는 `KR7005930003`입니다. 그러나 ISIN 코드는 12자리고 실무에서 사용하기에는 너무 길기 때문에 주식종목에 한하여 ISIN 코드 중 4번째 자리수부터 9번째 자리수까지의 6자리만을 사용하는 이른바 **"단축코드"**를 더 많이 사용합니다. 예를 들어 삼성전자의 단축코드는 `005930`입니다.
#
# `kquant` 패키지에서는 모든 금융상품에 대한 종목코드 정보를 제공합니다. 주식의 경우 `symbol_stock()` 함수를 사용하여 모든 주식의 종목코드 정보를 받을 수 있습니다. `symbol_stock()` 함수에 대한 자세한 정보는 `kquant` 패키지 [API 참조문서](../apiref/kquant/data/market/symbol/symbol_stock.html){target="_blank"}를 참조하세요.
#
# `symbol_stock()` 함수를 포함한 대부분의  `kquant` 패키지 함수는 Pandas 데이터프레임(DataFrame) 형식으로 정보를 반환합니다. Pandas 패키지에 대해서는 해당 패키지의 웹사이트([https://pandas.pydata.org/](https://pandas.pydata.org/){target="_blank})를 참조하세요.

# %%
df_symbols = kq.symbol_stock()
df_symbols
# Out:
#                ISIN  SYMBOL                NAME                NAME_EN  \
# 0      HK0000057197  900110  이스트아시아홀딩스     East Asia Holdings
# 1      HK0000214814  900270            헝셩그룹       HENG SHENG GROUP
# 2      HK0000295359  900260              로스웰               Rothwell
# 3      HK0000307485  900290                 GRT                    GRT
# 4      HK0000312568  900300    오가닉티코스메틱  ORGANIC TEA COSMETICS
# ...             ...     ...                 ...                    ...
# 3,754  KYG2114A1094  900120        씨케이에이치                    CKH
# 3,755  KYG2115T1076  900250      크리스탈신소재   Crystal New Material
# 3,756  KYG3931T1076  900070        글로벌에스엠                   GSMT
# 3,757  KYG5307W1015  900140    엘브이엠씨홀딩스          LVMC Holdings
# 3,758  USU652221081  900100            애머릿지               Ameridge
#
#       SEC_TYPE  ADMIN_ISSUE    MARKET
# 0           FS            0    코스닥
# 1           FS            0    코스닥
# 2           FS            0    코스닥
# 3           FS            0    코스닥
# 4           FS           91    코스닥
# ...        ...          ...       ...
# 3,754       FS            0    코스닥
# 3,755       FS            0    코스닥
# 3,756       FS            0    코스닥
# 3,757       FS            0  유가증권
# 3,758       FS            0    코스닥
#
# [3759 rows x 7 columns]

# %% [markdown]
# 종목이름으로 검색하려면 `search_symbol_stock()` 함수를 사용합니다.

# %%
kq.symbol_search_stock("한국").head(5)
# Out:
#            ISIN  SYMBOL            NAME            NAME_EN SEC_TYPE  \
# 0  KR7000240002  000240    한국앤컴퍼니  HANKOOK & COMPANY       ST
# 1  KR7000970004  000970      한국주철관    KorCastIronPipe       ST
# 2  KR7002200004  002200    한국수출포장      KorExptPkgInd       ST
# 3  KR7002960003  002960      한국쉘석유    HankookShellOil       ST
# 4  KR7003350006  003350  한국화장품제조     HKCManufacture       ST
#
#    ADMIN_ISSUE    MARKET
# 0            0  유가증권
# 1            0  유가증권
# 2            0  유가증권
# 3            0  유가증권
# 4            0  유가증권

# %% [markdown]
# ## 3.3 일간 주가정보

# %% [markdown]
# 원하는 종목의 종목코드를 확인한 다음에는 주가 등의 시장정보를 받을 수 있습니다.
#
# 일간 주가정보를 받기 위해서는 `daily_stock()` 함수를 사용합니다. `daily_stock()` 함수에 대한 자세한 정보는 `kquant` 패키지 [API 참조문서](../apiref/data/market/daily/daily_stock.html){target="_blank"}를 참조하세요.
#
# 첫번째 `symbol` 인수로는 해당 종목의 단축코드 문자열을 입력합니다. 예를 들어 삼성전자의 일간 주가정보를 얻기 위해서는 `"005930"`을 넣어줍니다.
#
# 두번째 `start_date` 인수로는 시장정보를 받을 기간의 시작날짜 문자열을 `YYYYMMDD` 형식으로 입력합니다. 예를 들어 2023년 1월 1일은 `"20230101"`과 같이 넣어줍니다.
#
# 세번째 `end_date` 인수로는 시장정보를 받을 기간의 종료날짜 문자열을 `YYYYMMDD` 형식으로 입력합니다. 예를 들어 2023년 6월 30일은 `"20230630"`과 같이 넣어줍니다.

# %%
df = kq.daily_stock("005930", "20230101", "20230630")
df
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2023-01-02  005930  55,500  56,100  55,200  55,500  10,031,448
# 1   2023-01-03  005930  55,400  56,000  54,500  55,400  13,547,030
# 2   2023-01-04  005930  55,700  58,000  55,600  57,800  20,188,071
# 3   2023-01-05  005930  58,200  58,800  57,600  58,200  15,682,826
# 4   2023-01-06  005930  58,300  59,400  57,900  59,000  17,334,989
# ..         ...     ...     ...     ...     ...     ...         ...
# 118 2023-06-26  005930  71,700  72,500  71,500  72,400  10,541,901
# 119 2023-06-27  005930  72,500  72,600  72,000  72,600   9,442,997
# 120 2023-06-28  005930  72,600  72,700  72,000  72,700   8,783,093
# 121 2023-06-29  005930  73,100  73,400  72,400  72,400  12,229,967
# 122 2023-06-30  005930  72,500  72,700  71,700  72,200  11,694,765
#
#                 AMOUNT    CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0      558,433,491,400    200   0.3600         2       00       55,500
# 1      747,898,872,200   -100  -0.1800         5       00       55,400
# 2    1,151,473,733,800  2,400   4.3300         2       00       55,700
# 3      911,973,904,900    400   0.6900         2       00       58,200
# 4    1,018,769,177,900    800   1.3700         2       00       58,300
# ..                 ...    ...      ...       ...      ...          ...
# 118    761,525,382,100    800   1.1200         2       00       71,700
# 119    683,624,715,982    200   0.2800         2       00       72,500
# 120    635,516,679,700    100   0.1400         2       00       72,600
# 121    891,731,369,446   -300  -0.4100         5       00       73,100
# 122    844,353,820,176   -200  -0.2800         5       00       72,500
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         56,100      55,200        55,500         200          0.3600
# 1         56,000      54,500        55,400        -100         -0.1800
# 2         58,000      55,600        57,800       2,400          4.3300
# 3         58,800      57,600        58,200         400          0.6900
# 4         59,400      57,900        59,000         800          1.3700
# ..           ...         ...           ...         ...             ...
# 118       72,500      71,500        72,400         800          1.1200
# 119       72,600      72,000        72,600         200          0.2800
# 120       72,700      72,000        72,700         100          0.1400
# 121       73,400      72,400        72,400        -300         -0.4100
# 122       72,700      71,700        72,200        -200         -0.2800
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 2  331,322,931,525,000  5,969,782,550
# 1                 5  330,725,953,270,000  5,969,782,550
# 2                 2  345,053,431,390,000  5,969,782,550
# 3                 2  347,441,344,410,000  5,969,782,550
# 4                 2  352,217,170,450,000  5,969,782,550
# ..              ...                  ...            ...
# 118               2  432,212,256,620,000  5,969,782,550
# 119               2  433,406,213,130,000  5,969,782,550
# 120               2  434,003,191,385,000  5,969,782,550
# 121               5  432,212,256,620,000  5,969,782,550
# 122               5  431,018,300,110,000  5,969,782,550
#
# [123 rows x 21 columns]

# %% [markdown]
# `end_date` 인수를 생략하면 함수를 실행한 당일을 `end_date` 인수값으로 가정하여 실시간 최종 가격을 출력합니다.
# 예를 들어 2023년 7월 18일 장종료후  `end_date` 인수를 생략하고 `daily_stock()` 함수를 실행한 결과는 다음과 같습니다.

# %%
kq.daily_stock("005930", "20230101")
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2023-01-02  005930  55,500  56,100  55,200  55,500  10,031,448
# 1   2023-01-03  005930  55,400  56,000  54,500  55,400  13,547,030
# 2   2023-01-04  005930  55,700  58,000  55,600  57,800  20,188,071
# 3   2023-01-05  005930  58,200  58,800  57,600  58,200  15,682,826
# 4   2023-01-06  005930  58,300  59,400  57,900  59,000  17,334,989
# ..         ...     ...     ...     ...     ...     ...         ...
# 154 2023-08-16  005930  66,700  67,100  66,300  67,000  13,174,578
# 155 2023-08-17  005930  66,300  66,800  66,000  66,700  10,778,652
# 156 2023-08-18  005930  66,000  66,700  65,800  66,300  11,745,006
# 157 2023-08-21  005930  66,600  67,100  66,300  66,600   9,720,067
# 158 2023-08-22  005930  67,200  67,700  66,300  66,600  10,469,653
#
#                 AMOUNT    CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0      558,433,491,400    200   0.3600         2       00       55,500
# 1      747,898,872,200   -100  -0.1800         5       00       55,400
# 2    1,151,473,733,800  2,400   4.3300         2       00       55,700
# 3      911,973,904,900    400   0.6900         2       00       58,200
# 4    1,018,769,177,900    800   1.3700         2       00       58,300
# ..                 ...    ...      ...       ...      ...          ...
# 154    879,111,210,400   -300  -0.4500         5       00       66,700
# 155    716,095,782,444   -300  -0.4500         5       00       66,300
# 156    778,550,834,100   -400  -0.6000         5       00       66,000
# 157    647,498,994,572    300   0.4500         2       00       66,600
# 158    700,110,094,200      0   0.0000         3       00       67,200
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         56,100      55,200        55,500         200          0.3600
# 1         56,000      54,500        55,400        -100         -0.1800
# 2         58,000      55,600        57,800       2,400          4.3300
# 3         58,800      57,600        58,200         400          0.6900
# 4         59,400      57,900        59,000         800          1.3700
# ..           ...         ...           ...         ...             ...
# 154       67,100      66,300        67,000        -300         -0.4500
# 155       66,800      66,000        66,700        -300         -0.4500
# 156       66,700      65,800        66,300        -400         -0.6000
# 157       67,100      66,300        66,600         300          0.4500
# 158       67,700      66,300        66,600           0          0.0000
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 2  331,322,931,525,000  5,969,782,550
# 1                 5  330,725,953,270,000  5,969,782,550
# 2                 2  345,053,431,390,000  5,969,782,550
# 3                 2  347,441,344,410,000  5,969,782,550
# 4                 2  352,217,170,450,000  5,969,782,550
# ..              ...                  ...            ...
# 154               5  399,975,430,850,000  5,969,782,550
# 155               5  398,184,496,085,000  5,969,782,550
# 156               5  395,796,583,065,000  5,969,782,550
# 157               2  397,587,517,830,000  5,969,782,550
# 158               3  397,587,517,830,000  5,969,782,550
#
# [159 rows x 21 columns]

# %% [markdown]
# `start_date` 인수를 생략하면 `end_date` 인수값으로 지정된 날짜의 1년 전을 가정하여 정보를 출력합니다.
# `start_date` 인수와 `end_date` 인수를 모두 생략하면 함수를 호출한 날로부터 1년전부터 당일까지의 정보를 출력합니다.

# %%
kq.daily_stock("005930")
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2022-08-22  005930  60,300  60,400  59,800  60,000   8,259,865
# 1   2022-08-23  005930  59,000  59,600  59,000  59,100   9,041,629
# 2   2022-08-24  005930  59,200  59,500  59,000  59,000   8,888,486
# 3   2022-08-25  005930  59,200  59,700  59,000  59,700   5,767,902
# 4   2022-08-26  005930  60,300  60,900  59,900  60,000   9,499,995
# ..         ...     ...     ...     ...     ...     ...         ...
# 244 2023-08-16  005930  66,700  67,100  66,300  67,000  13,174,578
# 245 2023-08-17  005930  66,300  66,800  66,000  66,700  10,778,652
# 246 2023-08-18  005930  66,000  66,700  65,800  66,300  11,745,006
# 247 2023-08-21  005930  66,600  67,100  66,300  66,600   9,720,067
# 248 2023-08-22  005930  67,200  67,700  66,300  66,600  10,469,653
#
#               AMOUNT   CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0    495,732,266,100  -900  -1.4800         5       00       60,300
# 1    535,657,353,300  -900  -1.5000         5       00       59,000
# 2    525,406,965,200  -100  -0.1700         5       00       59,200
# 3    342,780,937,200   700   1.1900         2       00       59,200
# 4    573,040,309,950   300   0.5000         2       00       60,300
# ..               ...   ...      ...       ...      ...          ...
# 244  879,111,210,400  -300  -0.4500         5       00       66,700
# 245  716,095,782,444  -300  -0.4500         5       00       66,300
# 246  778,550,834,100  -400  -0.6000         5       00       66,000
# 247  647,498,994,572   300   0.4500         2       00       66,600
# 248  700,110,094,200     0   0.0000         3       00       67,200
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         60,400      59,800        60,000        -900         -1.4800
# 1         59,600      59,000        59,100        -900         -1.5000
# 2         59,500      59,000        59,000        -100         -0.1700
# 3         59,700      59,000        59,700         700          1.1900
# 4         60,900      59,900        60,000         300          0.5000
# ..           ...         ...           ...         ...             ...
# 244       67,100      66,300        67,000        -300         -0.4500
# 245       66,800      66,000        66,700        -300         -0.4500
# 246       66,700      65,800        66,300        -400         -0.6000
# 247       67,100      66,300        66,600         300          0.4500
# 248       67,700      66,300        66,600           0          0.0000
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 5  358,186,953,000,000  5,969,782,550
# 1                 5  352,814,148,705,000  5,969,782,550
# 2                 5  352,217,170,450,000  5,969,782,550
# 3                 2  356,396,018,235,000  5,969,782,550
# 4                 2  358,186,953,000,000  5,969,782,550
# ..              ...                  ...            ...
# 244               5  399,975,430,850,000  5,969,782,550
# 245               5  398,184,496,085,000  5,969,782,550
# 246               5  395,796,583,065,000  5,969,782,550
# 247               2  397,587,517,830,000  5,969,782,550
# 248               3  397,587,517,830,000  5,969,782,550
#
# [249 rows x 21 columns]

# %% [markdown]
# ## 3.4 일중 주가정보

# %% [markdown]
# `intra_stock()` 함수는 호출 당일의 10초 또는 1분 간격 일중정보를 제공합니다.
#
# 시간 간격은 `interval` 인수의 값으로 설정하며 `"10S"`는 10초, `"10S"`는 1분 간격입니다.
# `interval` 인수의 값을 생략하면 1분으로 가정합니다.
#
# 10초 정보의 경우 거래소 상황에 따라 원 데이터 자체에 일부 데이터 누락이 있을 수 있습니다.

# %%
# 1분 간격 일중정보
kq.intra_stock("005930")
# Out:
#                DATETIME       DATE      TIME  SYMBOL        OPEN        HIGH  \
# 1   2023-08-22 09:00:00 2023-08-22  09:00:00  005930 67,200.0000 67,500.0000
# 2   2023-08-22 09:01:00 2023-08-22  09:01:00  005930 67,500.0000 67,700.0000
# 3   2023-08-22 09:02:00 2023-08-22  09:02:00  005930 67,400.0000 67,600.0000
# 4   2023-08-22 09:03:00 2023-08-22  09:03:00  005930 67,400.0000 67,500.0000
# 5   2023-08-22 09:04:00 2023-08-22  09:04:00  005930 67,400.0000 67,600.0000
# ..                  ...        ...       ...     ...         ...         ...
# 386 2023-08-22 15:25:00        NaT  15:25:00    <NA>         NaN         NaN
# 387 2023-08-22 15:26:00        NaT  15:26:00    <NA>         NaN         NaN
# 388 2023-08-22 15:27:00        NaT  15:27:00    <NA>         NaN         NaN
# 389 2023-08-22 15:28:00        NaT  15:28:00    <NA>         NaN         NaN
# 390 2023-08-22 15:29:00 2023-08-22  15:29:00  005930 66,600.0000 66,600.0000
#
#             LOW       CLOSE     VOLUME          AMOUNT      VOLUME_ACC  \
# 1   67,100.0000 67,500.0000    507,453  34,136,840,600    507,453.0000
# 2   67,300.0000 67,500.0000    467,114  31,545,499,300    974,567.0000
# 3   67,300.0000 67,400.0000    167,271  11,279,466,200  1,141,838.0000
# 4   67,300.0000 67,400.0000     35,311   2,380,589,500  1,177,149.0000
# 5   67,400.0000 67,500.0000    141,454   9,547,102,900  1,318,603.0000
# ..          ...         ...        ...             ...             ...
# 386         NaN         NaN          0               0             NaN
# 387         NaN         NaN          0               0             NaN
# 388         NaN         NaN          0               0             NaN
# 389         NaN         NaN          0               0             NaN
# 390 66,600.0000 66,600.0000  1,004,600  66,906,360,000 10,450,269.0000
#
#               AMOUNT_ACC      CHG  CHG_PCT  CHG_TYPE
# 1    34,136,840,600.0000 900.0000   1.3500    2.0000
# 2    65,682,339,900.0000 900.0000   1.3500    2.0000
# 3    76,961,806,100.0000 800.0000   1.2000    2.0000
# 4    79,342,395,600.0000 800.0000   1.2000    2.0000
# 5    88,889,498,500.0000 900.0000   1.3500    2.0000
# ..                   ...      ...      ...       ...
# 386                  NaN      NaN      NaN       NaN
# 387                  NaN      NaN      NaN       NaN
# 388                  NaN      NaN      NaN       NaN
# 389                  NaN      NaN      NaN       NaN
# 390 698,819,119,800.0000   0.0000   0.0000    3.0000
#
# [390 rows x 15 columns]

# %%
# 10초 간격 일중정보
kq.intra_stock("005930", "10S")
# Out:
#                  DATETIME       DATE      TIME  SYMBOL    OPEN    HIGH  \
# 0     2023-08-22 09:00:00 2023-08-22  09:00:00  005930  66,600  66,600
# 1     2023-08-22 09:00:10 2023-08-22  09:00:10  005930  67,200  67,300
# 2     2023-08-22 09:00:20 2023-08-22  09:00:20  005930  67,200  67,300
# 3     2023-08-22 09:00:30 2023-08-22  09:00:30  005930  67,300  67,400
# 4     2023-08-22 09:00:40 2023-08-22  09:00:40  005930  67,400  67,500
# ...                   ...        ...       ...     ...     ...     ...
# 2,277 2023-08-22 15:19:30 2023-08-22  15:19:30  005930  66,600  66,700
# 2,278 2023-08-22 15:19:40 2023-08-22  15:19:40  005930  66,600  66,700
# 2,279 2023-08-22 15:19:50 2023-08-22  15:19:50  005930  66,700  66,800
# 2,280 2023-08-22 15:20:00 2023-08-22  15:20:00  005930  66,800  66,800
# 2,281 2023-08-22 15:30:00 2023-08-22  15:30:00  005930  66,600  66,600
#
#           LOW   CLOSE     VOLUME          AMOUNT  VOLUME_ACC       AMOUNT_ACC  \
# 0      66,600  66,600          0               0           0                0
# 1      67,100  67,300    294,966  19,819,746,600     294,966   19,819,746,600
# 2      67,200  67,300      1,665     111,999,100     296,631   19,931,745,700
# 3      67,200  67,300     90,780   6,111,736,000     387,411   26,043,481,700
# 4      67,300  67,500     89,249   6,016,730,500     476,660   32,060,212,200
# ...       ...     ...        ...             ...         ...              ...
# 2,277  66,600  66,700      9,470     631,624,800   9,389,660  628,175,795,800
# 2,278  66,600  66,600     13,878     925,514,500   9,403,538  629,101,310,300
# 2,279  66,600  66,700     35,094   2,341,412,200   9,438,632  631,442,722,500
# 2,280  66,700  66,700      7,037     470,037,300   9,445,669  631,912,759,800
# 2,281  66,600  66,600  1,004,600  66,906,360,000  10,450,269  698,819,119,800
#
#        CHG  CHG_PCT  CHG_TYPE
# 0        0   0.0000         0
# 1      700   1.0500         2
# 2      700   1.0500         2
# 3      700   1.0500         2
# 4      900   1.3500         2
# ...    ...      ...       ...
# 2,277  100   0.1500         2
# 2,278    0   0.0000         3
# 2,279  100   0.1500         2
# 2,280  100   0.1500         2
# 2,281    0   0.0000         3
#
# [2282 rows x 15 columns]

# %% [markdown]
# ## 3.5 전종목 주가정보 동시 조회

# %% [markdown]
# `rank_stocks` 함수는 전 종목의 주가정보를 동시에 조회하는 함수입니다.

# %%
kq.rank_stocks()
# Out:
#        SYMBOL     OPEN     HIGH      LOW    CLOSE      VOLUME  \
# 0      005930   67,200   67,700   66,300   66,600  10,469,653
# 1      373220  531,000  542,000  531,000  539,000     193,477
# 2      000660  120,000  120,900  114,900  116,500   3,168,210
# 3      207940  780,000  782,000  770,000  773,000      30,770
# 4      005490  563,000  573,000  552,000  560,000   1,043,386
# ...       ...      ...      ...      ...      ...         ...
# 3,754  426410   12,620   12,620   12,510   12,510          23
# 3,755  287330    5,875    5,910    5,850    5,855         428
# 3,756  315480   10,635   10,635   10,545   10,545          36
# 3,757  287320   11,850   11,940   11,850   11,880          17
# 3,758  301440        0        0        0   10,255           0
#
#                 AMOUNT  PREV_CLOSE  CHG_PCT  CHG_TYPE            MARKETCAP  \
# 0      700,110,094,200      66,600   0.0000         3  397,587,517,830,000
# 1      104,082,606,000     526,000   2.4715         2  126,126,000,000,000
# 2      372,753,652,500     116,400   0.0859         2   84,812,275,522,500
# 3       23,803,552,000     778,000  -0.6427         5   55,017,502,000,000
# 4      585,200,522,000     551,000   1.6334         2   47,359,888,800,000
# ...                ...         ...      ...       ...                  ...
# 3,754          289,510      12,535  -0.1994         5        1,876,500,000
# 3,755        2,521,350       5,875  -0.3404         5        1,288,100,000
# 3,756          380,525      10,505   0.3808         2        1,265,400,000
# 3,757          202,685      11,890  -0.0841         5        1,188,000,000
# 3,758                0      10,255   0.0000         0        1,025,500,000
#
#                                NAME                                  NAME_EN  \
# 0                          삼성전자                              SamsungElec
# 1                    LG에너지솔루션                       LG Energy Solution
# 2                        SK하이닉스                                 SK hynix
# 3                  삼성바이오로직스                        SAMSUNG BIOLOGICS
# 4                       POSCO홀딩스                           POSCO Holdings
# ...                             ...                                      ...
# 3,754   ARIRANG 미국대체투자Top10MV  ARIRANG Top10 US Listed Alt Managers MV
# 3,755          KBSTAR 200생활소비재                       KBSTAR 200 Con&Sta
# 3,756  KBSTAR 200커뮤니케이션서비스                             KBSTAR 200CS
# 3,757              KBSTAR 200산업재                   KBSTAR 200 Industrials
# 3,758          ARIRANG 코스피중형주                     ARIRANG KOSPI MidCap
#
#       SEC_TYPE    MARKET
# 0           ST  유가증권
# 1           ST  유가증권
# 2           ST  유가증권
# 3           ST  유가증권
# 4           ST  유가증권
# ...        ...       ...
# 3,754       EF  유가증권
# 3,755       EF  유가증권
# 3,756       EF  유가증권
# 3,757       EF  유가증권
# 3,758       EF  유가증권
#
# [3759 rows x 15 columns]

# %% [markdown]
# `rank_stocks` 함수는 기본적으로 시가총액 기준으로 정렬한 결과를 출력합니다. `order_key` 인수를 사용하여 다양한 기준으로 정렬할 수 있습니다.

# %%
kq.rank_stocks(order_key="VOLUME")
# Out:
#        SYMBOL   OPEN   HIGH    LOW  CLOSE       VOLUME           AMOUNT  \
# 0      252670  2,670  2,715  2,650  2,690  114,342,262  306,291,641,590
# 1      025320  4,420  4,915  4,200  4,450   73,117,192  338,058,539,285
# 2      251340  3,560  3,605  3,545  3,565   72,457,068  258,491,508,730
# 3      214680  4,125  4,580  4,030  4,160   59,634,527  257,474,838,480
# 4      277410  2,830  3,480  2,730  3,480   54,563,628  179,815,169,050
# ...       ...    ...    ...    ...    ...          ...              ...
# 3,754  033180      0      0      0    442            0                0
# 3,755  030790      0      0      0    904            0                0
# 3,756  015540      0      0      0  6,410            0                0
# 3,757  019490      0      0      0  2,470            0                0
# 3,758  437780      0      0      0  2,180            0                0
#
#        PREV_CLOSE  CHG_PCT  CHG_TYPE          MARKETCAP  \
# 0           2,710  -0.7380         5  1,732,360,000,000
# 1           3,945  12.8010         2    343,676,886,450
# 2           3,605  -1.1096         5  1,107,645,500,000
# 3           3,780  10.0529         2    300,874,857,920
# 4           2,680  29.8507         1    125,898,009,720
# ...           ...      ...       ...                ...
# 3,754         442   0.0000         0     84,294,994,836
# 3,755         904   0.0000         0     19,208,323,080
# 3,756       6,410   0.0000         0    400,989,543,110
# 3,757       2,470   0.0000         0     68,199,723,280
# 3,758       2,180   0.0000         0     10,965,400,000
#
#                             NAME                       NAME_EN SEC_TYPE  \
# 0          KODEX 200선물인버스2X  KODEX 200 Futures Inverse 2X       EF
# 1                       시노펙스                       Synopex       ST
# 2      KODEX 코스닥150선물인버스       KODEX KOSDAQ150 INVERSE       EF
# 3                         디알텍                        DRTECH       ST
# 4                         인산가                         INSAN       ST
# ...                          ...                           ...      ...
# 3,754                  KH 필룩스                     KH FEELUX       ST
# 3,755                 비케이탑스                       BK TOPS       ST
# 3,756             쎌마테라퓨틱스           THELMA Therapeutics       ST
# 3,757                   하이트론                        Hitron       ST
# 3,758           엔에이치스팩24호                    NH SPAC 24       ST
#
#          MARKET
# 0      유가증권
# 1        코스닥
# 2      유가증권
# 3        코스닥
# 4        코스닥
# ...         ...
# 3,754  유가증권
# 3,755  유가증권
# 3,756  유가증권
# 3,757  유가증권
# 3,758    코스닥
#
# [3759 rows x 15 columns]
