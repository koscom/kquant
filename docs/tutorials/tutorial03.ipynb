# %% [markdown]
# # 튜토리얼 3 - 주가 정보 입수

# %% [markdown]
# 튜토리얼 2에서 CHECK-API 정보를 정상적으로 설정하였다면 본 튜토리얼에서 설명하는 대로 주가 정보를 입수할 수 있습니다.

# %% [markdown]
# ## 3.1 `kquant` 패키지 임포트

# %% [markdown]
# `kquant` 패키지를 임포트 합니다. 본 튜토리얼에서는 `kq`라는 별칭(alias)을 사용합니다.

# %%
import kquant as kq

# %% [markdown]
# ## 3.2 주식 ISIN 코드와 단축코드

# %% [markdown]
# 주식 등 금융상품에 대한 정보를 입수하기 위해서는 종목코드라고 부르는 해당 상품의 코드(code) 혹은 심볼(symbol)정보를 알고 있어야 합니다.
#
# 국내의 금융상품 코드는 공식적으로 12자리 영문자 및 숫자로 구성된 **국제증권식별번호**(ISIN: International Securities Identification Number)를 사용합니다. 예를 들어 삼성전자의 ISIN 코드는 `KR7005930003`입니다. 그러나 ISIN 코드는 12자리고 실무에서 사용하기에는 너무 길기 때문에 주식종목에 한하여 ISIN 코드 중 4번째 자리수부터 9번째 자리수까지의 6자리만을 사용하는 이른바 **"단축코드"**를 더 많이 사용합니다. 예를 들어 삼성전자의 단축코드는 `005930`입니다.
#
# `kquant` 패키지에서는 모든 금융상품에 대한 종목코드 정보를 제공합니다. 주식의 경우 `symbol_stock()` 함수를 사용하여 모든 주식의 종목코드 정보를 받을 수 있습니다. `symbol_stock()` 함수에 대한 자세한 정보는 `kquant` 패키지 [API 참조문서](../apiref/kquant/data/market/symbol/symbol_stock.html){target="_blank"}를 참조하세요.
#
# `symbol_stock()` 함수를 포함한 대부분의  `kquant` 패키지 함수는 Pandas 데이터프레임(DataFrame) 형식으로 정보를 반환합니다. Pandas 패키지에 대해서는 해당 패키지의 웹사이트([https://pandas.pydata.org/](https://pandas.pydata.org/){target="_blank})를 참조하세요.

# %%
df_symbols = kq.symbol_stock()
df_symbols
# Out:
#                ISIN  SYMBOL                NAME                NAME_EN  \
# 0      HK0000057197  900110  이스트아시아홀딩스     East Asia Holdings
# 1      HK0000214814  900270            헝셩그룹       HENG SHENG GROUP
# 2      HK0000295359  900260              로스웰               Rothwell
# 3      HK0000307485  900290                 GRT                    GRT
# 4      HK0000312568  900300    오가닉티코스메틱  ORGANIC TEA COSMETICS
# ...             ...     ...                 ...                    ...
# 3,748  KYG2114A1094  900120        씨케이에이치                    CKH
# 3,749  KYG2115T1076  900250      크리스탈신소재   Crystal New Material
# 3,750  KYG3931T1076  900070        글로벌에스엠                   GSMT
# 3,751  KYG5307W1015  900140    엘브이엠씨홀딩스          LVMC Holdings
# 3,752  USU652221081  900100            애머릿지               Ameridge
#
#       SEC_TYPE  ADMIN_ISSUE    MARKET
# 0           FS            0    코스닥
# 1           FS            0    코스닥
# 2           FS            0    코스닥
# 3           FS            0    코스닥
# 4           FS           91    코스닥
# ...        ...          ...       ...
# 3,748       FS            0    코스닥
# 3,749       FS            0    코스닥
# 3,750       FS            0    코스닥
# 3,751       FS            0  유가증권
# 3,752       FS            0    코스닥
#
# [3753 rows x 7 columns]

# %% [markdown]
# 종목이름으로 검색하려면 `search_symbol_stock()` 함수를 사용합니다.

# %%
kq.symbol_search_stock("한국").head(5)
# Out:
#            ISIN  SYMBOL            NAME            NAME_EN SEC_TYPE  \
# 0  KR7000240002  000240    한국앤컴퍼니  HANKOOK & COMPANY       ST
# 1  KR7000970004  000970      한국주철관    KorCastIronPipe       ST
# 2  KR7002200004  002200    한국수출포장      KorExptPkgInd       ST
# 3  KR7002960003  002960      한국쉘석유    HankookShellOil       ST
# 4  KR7003350006  003350  한국화장품제조     HKCManufacture       ST
#
#    ADMIN_ISSUE    MARKET
# 0            0  유가증권
# 1            0  유가증권
# 2            0  유가증권
# 3            0  유가증권
# 4            0  유가증권

# %% [markdown]
# ## 3.3 일간 주가정보

# %% [markdown]
# 원하는 종목의 종목코드를 확인한 다음에는 주가 등의 시장정보를 받을 수 있습니다.
#
# 일간 주가정보를 받기 위해서는 `daily_stock()` 함수를 사용합니다. `daily_stock()` 함수에 대한 자세한 정보는 `kquant` 패키지 [API 참조문서](../apiref/data/market/daily/daily_stock.html){target="_blank"}를 참조하세요.
#
# 첫번째 `symbol` 인수로는 해당 종목의 단축코드 문자열을 입력합니다. 예를 들어 삼성전자의 일간 주가정보를 얻기 위해서는 `"005930"`을 넣어줍니다.
#
# 두번째 `start_date` 인수로는 시장정보를 받을 기간의 시작날짜 문자열을 `YYYYMMDD` 형식으로 입력합니다. 예를 들어 2023년 1월 1일은 `"20230101"`과 같이 넣어줍니다.
#
# 세번째 `end_date` 인수로는 시장정보를 받을 기간의 종료날짜 문자열을 `YYYYMMDD` 형식으로 입력합니다. 예를 들어 2023년 6월 30일은 `"20230630"`과 같이 넣어줍니다.

# %%
df = kq.daily_stock("005930", "20230101", "20230630")
df
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2023-01-02  005930  55,500  56,100  55,200  55,500  10,031,448
# 1   2023-01-03  005930  55,400  56,000  54,500  55,400  13,547,030
# 2   2023-01-04  005930  55,700  58,000  55,600  57,800  20,188,071
# 3   2023-01-05  005930  58,200  58,800  57,600  58,200  15,682,826
# 4   2023-01-06  005930  58,300  59,400  57,900  59,000  17,334,989
# ..         ...     ...     ...     ...     ...     ...         ...
# 118 2023-06-26  005930  71,700  72,500  71,500  72,400  10,541,901
# 119 2023-06-27  005930  72,500  72,600  72,000  72,600   9,442,997
# 120 2023-06-28  005930  72,600  72,700  72,000  72,700   8,783,093
# 121 2023-06-29  005930  73,100  73,400  72,400  72,400  12,229,967
# 122 2023-06-30  005930  72,500  72,700  71,700  72,200  11,694,765
#
#                 AMOUNT    CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0      558,433,491,400    200   0.3600         2       00       55,500
# 1      747,898,872,200   -100  -0.1800         5       00       55,400
# 2    1,151,473,733,800  2,400   4.3300         2       00       55,700
# 3      911,973,904,900    400   0.6900         2       00       58,200
# 4    1,018,769,177,900    800   1.3700         2       00       58,300
# ..                 ...    ...      ...       ...      ...          ...
# 118    761,525,382,100    800   1.1200         2       00       71,700
# 119    683,624,715,982    200   0.2800         2       00       72,500
# 120    635,516,679,700    100   0.1400         2       00       72,600
# 121    891,731,369,446   -300  -0.4100         5       00       73,100
# 122    844,353,820,176   -200  -0.2800         5       00       72,500
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         56,100      55,200        55,500         200          0.3600
# 1         56,000      54,500        55,400        -100         -0.1800
# 2         58,000      55,600        57,800       2,400          4.3300
# 3         58,800      57,600        58,200         400          0.6900
# 4         59,400      57,900        59,000         800          1.3700
# ..           ...         ...           ...         ...             ...
# 118       72,500      71,500        72,400         800          1.1200
# 119       72,600      72,000        72,600         200          0.2800
# 120       72,700      72,000        72,700         100          0.1400
# 121       73,400      72,400        72,400        -300         -0.4100
# 122       72,700      71,700        72,200        -200         -0.2800
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 2  331,322,931,525,000  5,969,782,550
# 1                 5  330,725,953,270,000  5,969,782,550
# 2                 2  345,053,431,390,000  5,969,782,550
# 3                 2  347,441,344,410,000  5,969,782,550
# 4                 2  352,217,170,450,000  5,969,782,550
# ..              ...                  ...            ...
# 118               2  432,212,256,620,000  5,969,782,550
# 119               2  433,406,213,130,000  5,969,782,550
# 120               2  434,003,191,385,000  5,969,782,550
# 121               5  432,212,256,620,000  5,969,782,550
# 122               5  431,018,300,110,000  5,969,782,550
#
# [123 rows x 21 columns]

# %% [markdown]
# `end_date` 인수를 생략하면 함수를 실행한 당일을 `end_date` 인수값으로 가정하여 실시간 최종 가격을 출력합니다.
# 예를 들어 2023년 7월 18일 장종료후  `end_date` 인수를 생략하고 `daily_stock()` 함수를 실행한 결과는 다음과 같습니다.

# %%
kq.daily_stock("005930", "20230101")
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2023-01-02  005930  55,500  56,100  55,200  55,500  10,031,448
# 1   2023-01-03  005930  55,400  56,000  54,500  55,400  13,547,030
# 2   2023-01-04  005930  55,700  58,000  55,600  57,800  20,188,071
# 3   2023-01-05  005930  58,200  58,800  57,600  58,200  15,682,826
# 4   2023-01-06  005930  58,300  59,400  57,900  59,000  17,334,989
# ..         ...     ...     ...     ...     ...     ...         ...
# 158 2023-08-22  005930  67,200  67,700  66,300  66,600  10,500,242
# 159 2023-08-23  005930  66,700  67,100  66,400  67,100   9,549,352
# 160 2023-08-24  005930  68,300  68,700  67,900  68,200  15,044,463
# 161 2023-08-25  005930  67,100  67,400  66,900  67,100   7,032,462
# 162 2023-08-28  005930  66,800  67,000  66,600  66,700   2,868,953
#
#                 AMOUNT     CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0      558,433,491,400     200   0.3600         2       00       55,500
# 1      747,898,872,200    -100  -0.1800         5       00       55,400
# 2    1,151,473,733,800   2,400   4.3300         2       00       55,700
# 3      911,973,904,900     400   0.6900         2       00       58,200
# 4    1,018,769,177,900     800   1.3700         2       00       58,300
# ..                 ...     ...      ...       ...      ...          ...
# 158    702,152,276,000       0   0.0000         3       00       67,200
# 159    638,222,447,700     500   0.7500         2       00       66,700
# 160  1,026,978,314,909   1,100   1.6400         2       00       68,300
# 161    471,934,306,900  -1,100  -1.6100         5       00       67,100
# 162    191,495,542,800    -400  -0.6000         5       00       66,800
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         56,100      55,200        55,500         200          0.3600
# 1         56,000      54,500        55,400        -100         -0.1800
# 2         58,000      55,600        57,800       2,400          4.3300
# 3         58,800      57,600        58,200         400          0.6900
# 4         59,400      57,900        59,000         800          1.3700
# ..           ...         ...           ...         ...             ...
# 158       67,700      66,300        66,600           0          0.0000
# 159       67,100      66,400        67,100         500          0.7500
# 160       68,700      67,900        68,200       1,100          1.6400
# 161       67,400      66,900        67,100      -1,100         -1.6100
# 162       67,000      66,600        66,700        -400         -0.6000
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 2  331,322,931,525,000  5,969,782,550
# 1                 5  330,725,953,270,000  5,969,782,550
# 2                 2  345,053,431,390,000  5,969,782,550
# 3                 2  347,441,344,410,000  5,969,782,550
# 4                 2  352,217,170,450,000  5,969,782,550
# ..              ...                  ...            ...
# 158               3  397,587,517,830,000  5,969,782,550
# 159               2  400,572,409,105,000  5,969,782,550
# 160               2  407,139,169,910,000  5,969,782,550
# 161               5  400,572,409,105,000  5,969,782,550
# 162               5  398,184,496,085,000  5,969,782,550
#
# [163 rows x 21 columns]

# %% [markdown]
# `start_date` 인수를 생략하면 `end_date` 인수값으로 지정된 날짜의 1년 전을 가정하여 정보를 출력합니다.
# `start_date` 인수와 `end_date` 인수를 모두 생략하면 함수를 호출한 날로부터 1년전부터 당일까지의 정보를 출력합니다.

# %%
kq.daily_stock("005930")
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2022-08-29  005930  58,700  58,900  58,600  58,600   9,841,329
# 1   2022-08-30  005930  58,700  59,000  58,300  58,800   9,690,044
# 2   2022-08-31  005930  58,200  59,900  58,200  59,700  14,203,512
# 3   2022-09-01  005930  58,700  58,900  58,300  58,400  14,905,777
# 4   2022-09-02  005930  58,300  58,600  57,500  57,500  15,040,310
# ..         ...     ...     ...     ...     ...     ...         ...
# 243 2023-08-22  005930  67,200  67,700  66,300  66,600  10,500,242
# 244 2023-08-23  005930  66,700  67,100  66,400  67,100   9,549,352
# 245 2023-08-24  005930  68,300  68,700  67,900  68,200  15,044,463
# 246 2023-08-25  005930  67,100  67,400  66,900  67,100   7,032,462
# 247 2023-08-28  005930  66,800  67,000  66,600  66,800   2,868,966
#
#                 AMOUNT     CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0      577,684,200,900  -1,400  -2.3300         5       00       58,700
# 1      567,627,668,500     200   0.3400         2       00       58,700
# 2      841,319,635,900     900   1.5300         2       00       58,200
# 3      872,374,620,601  -1,300  -2.1800         5       00       58,700
# 4      872,040,367,551    -900  -1.5400         5       00       58,300
# ..                 ...     ...      ...       ...      ...          ...
# 243    702,152,276,000       0   0.0000         3       00       67,200
# 244    638,222,447,700     500   0.7500         2       00       66,700
# 245  1,026,978,314,909   1,100   1.6400         2       00       68,300
# 246    471,934,306,900  -1,100  -1.6100         5       00       67,100
# 247    191,496,411,200    -300  -0.4500         5       00       66,800
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         58,900      58,600        58,600      -1,400         -2.3300
# 1         59,000      58,300        58,800         200          0.3400
# 2         59,900      58,200        59,700         900          1.5300
# 3         58,900      58,300        58,400      -1,300         -2.1800
# 4         58,600      57,500        57,500        -900         -1.5400
# ..           ...         ...           ...         ...             ...
# 243       67,700      66,300        66,600           0          0.0000
# 244       67,100      66,400        67,100         500          0.7500
# 245       68,700      67,900        68,200       1,100          1.6400
# 246       67,400      66,900        67,100      -1,100         -1.6100
# 247       67,000      66,600        66,800        -300         -0.4500
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 5  349,829,257,430,000  5,969,782,550
# 1                 2  351,023,213,940,000  5,969,782,550
# 2                 2  356,396,018,235,000  5,969,782,550
# 3                 5  348,635,300,920,000  5,969,782,550
# 4                 5  343,262,496,625,000  5,969,782,550
# ..              ...                  ...            ...
# 243               3  397,587,517,830,000  5,969,782,550
# 244               2  400,572,409,105,000  5,969,782,550
# 245               2  407,139,169,910,000  5,969,782,550
# 246               5  400,572,409,105,000  5,969,782,550
# 247               5  398,781,474,340,000  5,969,782,550
#
# [248 rows x 21 columns]

# %% [markdown]
# ## 3.4 일중 주가정보

# %% [markdown]
# `intra_stock()` 함수는 호출 당일의 10초 또는 1분 간격 일중정보를 제공합니다.
#
# 시간 간격은 `interval` 인수의 값으로 설정하며 `"10S"`는 10초, `"1M"`는 1분 간격입니다.
# `interval` 인수의 값을 생략하면 1분으로 가정합니다.
#
# 10초 정보의 경우 거래소 상황에 따라 원 데이터 자체에 일부 데이터 누락이 있을 수 있습니다.

# %%
# 1분 간격 일중정보
kq.intra_stock("005930")
# Out:
#                DATETIME       DATE      TIME  SYMBOL    OPEN    HIGH     LOW  \
# 1   2023-08-28 09:00:00 2023-08-28  09:00:00  005930  66,800  67,000  66,700
# 2   2023-08-28 09:01:00 2023-08-28  09:01:00  005930  66,700  66,800  66,600
# 3   2023-08-28 09:02:00 2023-08-28  09:02:00  005930  66,700  66,700  66,600
# 4   2023-08-28 09:03:00 2023-08-28  09:03:00  005930  66,700  66,700  66,600
# 5   2023-08-28 09:04:00 2023-08-28  09:04:00  005930  66,600  66,900  66,600
# ..                  ...        ...       ...     ...     ...     ...     ...
# 137 2023-08-28 11:16:00 2023-08-28  11:16:00  005930  66,700  66,800  66,700
# 138 2023-08-28 11:17:00 2023-08-28  11:17:00  005930  66,800  66,800  66,700
# 139 2023-08-28 11:18:00 2023-08-28  11:18:00  005930  66,800  66,800  66,700
# 140 2023-08-28 11:19:00 2023-08-28  11:19:00  005930  66,700  66,800  66,700
# 141 2023-08-28 11:20:00 2023-08-28  11:20:00  005930  66,700  66,800  66,700
#
#       CLOSE   VOLUME          AMOUNT  VOLUME_ACC       AMOUNT_ACC   CHG  \
# 1    66,800  653,195  43,628,173,800     653,195   43,628,173,800  -300
# 2    66,600  138,247   9,220,213,900     791,442   52,848,387,700  -500
# 3    66,700   30,345   2,023,288,800     821,787   54,871,676,500  -400
# 4    66,700   27,351   1,823,568,900     849,138   56,695,245,400  -400
# 5    66,700  144,181   9,624,203,900     993,319   66,319,449,300  -400
# ..      ...      ...             ...         ...              ...   ...
# 137  66,800    3,257     217,341,900   2,854,249  190,514,506,700  -300
# 138  66,700    4,821     321,712,200   2,859,070  190,836,218,900  -400
# 139  66,800    4,012     267,652,900   2,863,082  191,103,871,800  -300
# 140  66,800    2,513     167,659,100   2,865,595  191,271,530,900  -300
# 141  66,700    2,477     165,247,500   2,868,072  191,436,778,400  -400
#
#      CHG_PCT  CHG_TYPE
# 1    -0.4500         5
# 2    -0.7500         5
# 3    -0.6000         5
# 4    -0.6000         5
# 5    -0.6000         5
# ..       ...       ...
# 137  -0.4500         5
# 138  -0.6000         5
# 139  -0.4500         5
# 140  -0.4500         5
# 141  -0.6000         5
#
# [141 rows x 15 columns]

# %%
# 10초 간격 일중정보
kq.intra_stock("005930", "10S")
# Out:
#                DATETIME       DATE      TIME  SYMBOL    OPEN    HIGH     LOW  \
# 0   2023-08-28 09:00:00 2023-08-28  09:00:00  005930  67,100  67,100  67,100
# 1   2023-08-28 09:00:30 2023-08-28  09:00:30  005930  66,800  67,000  66,800
# 2   2023-08-28 09:00:40 2023-08-28  09:00:40  005930  66,900  66,900  66,800
# 3   2023-08-28 09:00:50 2023-08-28  09:00:50  005930  66,900  66,900  66,800
# 4   2023-08-28 09:01:00 2023-08-28  09:01:00  005930  66,800  66,800  66,700
# ..                  ...        ...       ...     ...     ...     ...     ...
# 838 2023-08-28 11:20:00 2023-08-28  11:20:00  005930  66,800  66,800  66,700
# 839 2023-08-28 11:20:10 2023-08-28  11:20:10  005930  66,700  66,800  66,700
# 840 2023-08-28 11:20:20 2023-08-28  11:20:20  005930  66,700  66,800  66,700
# 841 2023-08-28 11:20:30 2023-08-28  11:20:30  005930  66,700  66,800  66,700
# 842 2023-08-28 11:20:40 2023-08-28  11:20:40  005930  66,800  66,800  66,700
#
#       CLOSE   VOLUME          AMOUNT  VOLUME_ACC       AMOUNT_ACC   CHG  \
# 0    67,100        0               0           0                0     0
# 1    66,900  496,261  33,152,504,200     496,261   33,152,504,200  -200
# 2    66,900   52,900   3,534,008,000     549,161   36,686,512,200  -200
# 3    66,800   17,342   1,158,588,900     566,503   37,845,101,100  -300
# 4    66,800   86,692   5,783,072,700     653,195   43,628,173,800  -300
# ..      ...      ...             ...         ...              ...   ...
# 838  66,800      833      55,574,300   2,865,595  191,271,530,900  -300
# 839  66,700      658      43,910,400   2,866,253  191,315,441,300  -400
# 840  66,700      990      66,037,100   2,867,243  191,381,478,400  -400
# 841  66,700      161      10,743,800   2,867,404  191,392,222,200  -400
# 842  66,700      668      44,556,200   2,868,072  191,436,778,400  -400
#
#      CHG_PCT  CHG_TYPE
# 0     0.0000         0
# 1    -0.3000         5
# 2    -0.3000         5
# 3    -0.4500         5
# 4    -0.4500         5
# ..       ...       ...
# 838  -0.4500         5
# 839  -0.6000         5
# 840  -0.6000         5
# 841  -0.6000         5
# 842  -0.6000         5
#
# [843 rows x 15 columns]

# %% [markdown]
# ## 3.5 전종목 주가정보 동시 조회

# %% [markdown]
# `rank_stocks` 함수는 전 종목의 주가정보를 동시에 조회하는 함수입니다.

# %%
kq.rank_stocks()
# Out:
#        SYMBOL     OPEN     HIGH      LOW    CLOSE     VOLUME           AMOUNT  \
# 0      005930   66,800   67,000   66,600   66,700  2,868,971  191,496,744,700
# 1      373220  550,000  553,000  542,000  551,000    112,626   61,804,061,000
# 2      000660  117,000  117,500  115,500  116,300    936,351  109,166,212,800
# 3      207940  763,000  764,000  746,000  748,000     20,922   15,699,280,000
# 4      005490  588,000  599,000  582,000  592,000    625,643  369,648,323,000
# ...       ...      ...      ...      ...      ...        ...              ...
# 3,748  433870   10,785   10,795   10,785   10,795          2           21,580
# 3,749  426410   12,545   12,545   12,405   12,500        866       10,811,600
# 3,750  287330    6,035    6,055    6,015    6,020        219        1,317,825
# 3,751  315480   10,480   10,480   10,440   10,450         12          125,690
# 3,752  287320   12,000   12,140   12,000   12,140          2           24,140
#
#        PREV_CLOSE  CHG_PCT  CHG_TYPE            MARKETCAP  \
# 0          67,100  -0.5961         5  398,184,496,085,000
# 1         546,000   0.9158         2  128,934,000,000,000
# 2         116,500  -0.1717         5   84,666,675,049,500
# 3         757,000  -1.1889         5   53,238,152,000,000
# 4         577,000   2.5997         2   50,066,168,160,000
# ...           ...      ...       ...                  ...
# 3,748      10,760   0.3253         2        1,943,100,000
# 3,749      12,400   0.8065         2        1,875,000,000
# 3,750       5,970   0.8375         2        1,324,400,000
# 3,751      10,465  -0.1433         5        1,254,000,000
# 3,752      11,965   1.4626         2        1,214,000,000
#
#                                NAME                                  NAME_EN  \
# 0                          삼성전자                              SamsungElec
# 1                    LG에너지솔루션                       LG Energy Solution
# 2                        SK하이닉스                                 SK hynix
# 3                  삼성바이오로직스                        SAMSUNG BIOLOGICS
# 4                       POSCO홀딩스                           POSCO Holdings
# ...                             ...                                      ...
# 3,748         ARIRANG TDF2050액티브                   ARIRANG TDF2050 Active
# 3,749   ARIRANG 미국대체투자Top10MV  ARIRANG Top10 US Listed Alt Managers MV
# 3,750          KBSTAR 200생활소비재                       KBSTAR 200 Con&Sta
# 3,751  KBSTAR 200커뮤니케이션서비스                             KBSTAR 200CS
# 3,752              KBSTAR 200산업재                   KBSTAR 200 Industrials
#
#       SEC_TYPE    MARKET
# 0           ST  유가증권
# 1           ST  유가증권
# 2           ST  유가증권
# 3           ST  유가증권
# 4           ST  유가증권
# ...        ...       ...
# 3,748       EF  유가증권
# 3,749       EF  유가증권
# 3,750       EF  유가증권
# 3,751       EF  유가증권
# 3,752       EF  유가증권
#
# [3753 rows x 15 columns]

# %% [markdown]
# `rank_stocks` 함수는 기본적으로 시가총액 기준으로 정렬한 결과를 출력합니다. `order_key` 인수를 사용하여 다양한 기준으로 정렬할 수 있습니다.

# %%
kq.rank_stocks(order_key="VOLUME")
# Out:
#        SYMBOL   OPEN   HIGH    LOW   CLOSE      VOLUME           AMOUNT  \
# 0      252670  2,655  2,680  2,645   2,655  55,496,623  147,527,778,020
# 1      900310  1,493  1,594  1,438   1,463  39,480,793   59,580,295,426
# 2      900340  1,680  1,697  1,528   1,566  30,502,881   48,777,277,543
# 3      046970  2,320  2,520  2,105   2,315  28,399,960   66,854,496,895
# 4      251340  3,525  3,570  3,520   3,550  24,469,392   86,710,322,510
# ...       ...    ...    ...    ...     ...         ...              ...
# 3,748  223190      0      0      0   9,505           0                0
# 3,749  244620      0      0      0  12,500           0                0
# 3,750  215620      0      0      0  11,330           0                0
# 3,751  244660      0      0      0   8,205           0                0
# 3,752  068940      0      0      0     778           0                0
#
#        PREV_CLOSE  CHG_PCT  CHG_TYPE          MARKETCAP  \
# 0           2,690  -1.3011         5  1,696,014,000,000
# 1           1,423   2.8110         2     93,692,970,525
# 2           1,423  10.0492         2     75,126,388,248
# 3           2,290   1.0917         2     74,194,902,710
# 4           3,560  -0.2809         5    951,755,000,000
# ...           ...      ...       ...                ...
# 3,748       9,505   0.0000         0     13,307,000,000
# 3,749      12,500   0.0000         0      8,750,000,000
# 3,750      11,330   0.0000         0      5,098,500,000
# 3,751       8,205   0.0000         0      4,102,500,000
# 3,752         778   0.0000         0     29,766,744,466
#
#                             NAME                       NAME_EN SEC_TYPE  \
# 0          KODEX 200선물인버스2X  KODEX 200 Futures Inverse 2X       EF
# 1                       컬러레이                       Coloray       FS
# 2                       윙입푸드                 WING YIP FOOD       FS
# 3                         우리로                       WOORIRO       ST
# 4      KODEX 코스닥150선물인버스       KODEX KOSDAQ150 INVERSE       EF
# ...                          ...                           ...      ...
# 3,748        KODEX 200가치저변동     KODEX 200 Intrinsic Value       EF
# 3,749           KODEX 모멘텀Plus           KODEX Momentum Plus       EF
# 3,750         HK S&P코리아로우볼           HK S&P Korea LowVol       EF
# 3,751           KODEX 퀄리티Plus            KODEX Quality Plus       EF
# 3,752                 셀피글로벌                Cellfie Global       ST
#
#          MARKET
# 0      유가증권
# 1        코스닥
# 2        코스닥
# 3        코스닥
# 4      유가증권
# ...         ...
# 3,748  유가증권
# 3,749  유가증권
# 3,750  유가증권
# 3,751  유가증권
# 3,752    코스닥
#
# [3753 rows x 15 columns]
