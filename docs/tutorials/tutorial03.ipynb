# %% [markdown]
# # 튜토리얼 3 - 주가 정보 입수

# %% [markdown]
# 튜토리얼 2에서 CHECK-API 정보를 정상적으로 설정하였다면 본 튜토리얼에서 설명하는 대로 주가 정보를 입수할 수 있습니다.

# %% [markdown]
# ## 3.1 `kquant` 패키지 임포트

# %% [markdown]
# `kquant` 패키지를 임포트 합니다. 본 튜토리얼에서는 `kq`라는 별칭(alias)을 사용합니다.

# %%
import kquant as kq

# %% [markdown]
# ## 3.2 주식 ISIN 코드와 단축코드

# %% [markdown]
# 주식 등 금융상품에 대한 정보를 입수하기 위해서는 종목코드라고 부르는 해당 상품의 코드(code) 혹은 심볼(symbol)정보를 알고 있어야 합니다.
#
# 국내의 금융상품 코드는 공식적으로 12자리 영문자 및 숫자로 구성된 **국제증권식별번호**(ISIN: International Securities Identification Number)를 사용합니다. 예를 들어 삼성전자의 ISIN 코드는 `KR7005930003`입니다. 그러나 ISIN 코드는 12자리고 실무에서 사용하기에는 너무 길기 때문에 주식종목에 한하여 ISIN 코드 중 4번째 자리수부터 9번째 자리수까지의 6자리만을 사용하는 이른바 **"단축코드"**를 더 많이 사용합니다. 예를 들어 삼성전자의 단축코드는 `005930`입니다.
#
# `kquant` 패키지에서는 모든 금융상품에 대한 종목코드 정보를 제공합니다. 주식의 경우 `symbol_stock()` 함수를 사용하여 모든 주식의 종목코드 정보를 받을 수 있습니다. `symbol_stock()` 함수에 대한 자세한 정보는 `kquant` 패키지 [API 참조문서](../apiref/kquant/data/market/symbol/symbol_stock.html){target="_blank"}를 참조하세요.
#
# `symbol_stock()` 함수를 포함한 대부분의  `kquant` 패키지 함수는 Pandas 데이터프레임(DataFrame) 형식으로 정보를 반환합니다. Pandas 패키지에 대해서는 해당 패키지의 웹사이트([https://pandas.pydata.org/](https://pandas.pydata.org/){target="_blank})를 참조하세요.

# %%
df_symbols = kq.symbol_stock()
df_symbols
# Out:
#                ISIN  SYMBOL                NAME                NAME_EN  \
# 0      HK0000057197  900110  이스트아시아홀딩스     East Asia Holdings
# 1      HK0000214814  900270            헝셩그룹       HENG SHENG GROUP
# 2      HK0000295359  900260              로스웰               Rothwell
# 3      HK0000307485  900290                 GRT                    GRT
# 4      HK0000312568  900300    오가닉티코스메틱  ORGANIC TEA COSMETICS
# ...             ...     ...                 ...                    ...
# 3,754  KYG2114A1094  900120        씨케이에이치                    CKH
# 3,755  KYG2115T1076  900250      크리스탈신소재   Crystal New Material
# 3,756  KYG3931T1076  900070        글로벌에스엠                   GSMT
# 3,757  KYG5307W1015  900140    엘브이엠씨홀딩스          LVMC Holdings
# 3,758  USU652221081  900100            애머릿지               Ameridge
#
#       SEC_TYPE  ADMIN_ISSUE    MARKET
# 0           FS            0    코스닥
# 1           FS            0    코스닥
# 2           FS            0    코스닥
# 3           FS            0    코스닥
# 4           FS           91    코스닥
# ...        ...          ...       ...
# 3,754       FS            0    코스닥
# 3,755       FS            0    코스닥
# 3,756       FS            0    코스닥
# 3,757       FS            0  유가증권
# 3,758       FS            0    코스닥
#
# [3759 rows x 7 columns]

# %% [markdown]
# 종목이름으로 검색하려면 `search_symbol_stock()` 함수를 사용합니다.

# %%
kq.symbol_search_stock("한국").head(5)
# Out:
#            ISIN  SYMBOL            NAME            NAME_EN SEC_TYPE  \
# 0  KR7000240002  000240    한국앤컴퍼니  HANKOOK & COMPANY       ST
# 1  KR7000970004  000970      한국주철관    KorCastIronPipe       ST
# 2  KR7002200004  002200    한국수출포장      KorExptPkgInd       ST
# 3  KR7002960003  002960      한국쉘석유    HankookShellOil       ST
# 4  KR7003350006  003350  한국화장품제조     HKCManufacture       ST
#
#    ADMIN_ISSUE    MARKET
# 0           91  유가증권
# 1            0  유가증권
# 2            0  유가증권
# 3            0  유가증권
# 4            0  유가증권

# %% [markdown]
# ## 3.3 일간 주가정보

# %% [markdown]
# 원하는 종목의 종목코드를 확인한 다음에는 주가 등의 시장정보를 받을 수 있습니다.
#
# 일간 주가정보를 받기 위해서는 `daily_stock()` 함수를 사용합니다. `daily_stock()` 함수에 대한 자세한 정보는 `kquant` 패키지 [API 참조문서](../apiref/data/market/daily/daily_stock.html){target="_blank"}를 참조하세요.
#
# 첫번째 `symbol` 인수로는 해당 종목의 단축코드 문자열을 입력합니다. 예를 들어 삼성전자의 일간 주가정보를 얻기 위해서는 `"005930"`을 넣어줍니다.
#
# 두번째 `start_date` 인수로는 시장정보를 받을 기간의 시작날짜 문자열을 `YYYYMMDD` 형식으로 입력합니다. 예를 들어 2023년 1월 1일은 `"20230101"`과 같이 넣어줍니다.
#
# 세번째 `end_date` 인수로는 시장정보를 받을 기간의 종료날짜 문자열을 `YYYYMMDD` 형식으로 입력합니다. 예를 들어 2023년 6월 30일은 `"20230630"`과 같이 넣어줍니다.

# %%
df = kq.daily_stock("005930", "20230101", "20230630")
df
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2023-01-02  005930  55,500  56,100  55,200  55,500  10,031,448
# 1   2023-01-03  005930  55,400  56,000  54,500  55,400  13,547,030
# 2   2023-01-04  005930  55,700  58,000  55,600  57,800  20,188,071
# 3   2023-01-05  005930  58,200  58,800  57,600  58,200  15,682,826
# 4   2023-01-06  005930  58,300  59,400  57,900  59,000  17,334,989
# ..         ...     ...     ...     ...     ...     ...         ...
# 118 2023-06-26  005930  71,700  72,500  71,500  72,400  10,541,901
# 119 2023-06-27  005930  72,500  72,600  72,000  72,600   9,442,997
# 120 2023-06-28  005930  72,600  72,700  72,000  72,700   8,783,093
# 121 2023-06-29  005930  73,100  73,400  72,400  72,400  12,229,967
# 122 2023-06-30  005930  72,500  72,700  71,700  72,200  11,694,765
#
#                 AMOUNT    CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0      558,433,491,400    200   0.3600         2       00       55,500
# 1      747,898,872,200   -100  -0.1800         5       00       55,400
# 2    1,151,473,733,800  2,400   4.3300         2       00       55,700
# 3      911,973,904,900    400   0.6900         2       00       58,200
# 4    1,018,769,177,900    800   1.3700         2       00       58,300
# ..                 ...    ...      ...       ...      ...          ...
# 118    761,525,382,100    800   1.1200         2       00       71,700
# 119    683,624,715,982    200   0.2800         2       00       72,500
# 120    635,516,679,700    100   0.1400         2       00       72,600
# 121    891,731,369,446   -300  -0.4100         5       00       73,100
# 122    844,353,820,176   -200  -0.2800         5       00       72,500
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         56,100      55,200        55,500         200          0.3600
# 1         56,000      54,500        55,400        -100         -0.1800
# 2         58,000      55,600        57,800       2,400          4.3300
# 3         58,800      57,600        58,200         400          0.6900
# 4         59,400      57,900        59,000         800          1.3700
# ..           ...         ...           ...         ...             ...
# 118       72,500      71,500        72,400         800          1.1200
# 119       72,600      72,000        72,600         200          0.2800
# 120       72,700      72,000        72,700         100          0.1400
# 121       73,400      72,400        72,400        -300         -0.4100
# 122       72,700      71,700        72,200        -200         -0.2800
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 2  331,322,931,525,000  5,969,782,550
# 1                 5  330,725,953,270,000  5,969,782,550
# 2                 2  345,053,431,390,000  5,969,782,550
# 3                 2  347,441,344,410,000  5,969,782,550
# 4                 2  352,217,170,450,000  5,969,782,550
# ..              ...                  ...            ...
# 118               2  432,212,256,620,000  5,969,782,550
# 119               2  433,406,213,130,000  5,969,782,550
# 120               2  434,003,191,385,000  5,969,782,550
# 121               5  432,212,256,620,000  5,969,782,550
# 122               5  431,018,300,110,000  5,969,782,550
#
# [123 rows x 21 columns]

# %% [markdown]
# `end_date` 인수를 생략하면 함수를 실행한 당일을 `end_date` 인수값으로 가정하여 실시간 최종 가격을 출력합니다.
# 예를 들어 2023년 7월 18일 장종료후  `end_date` 인수를 생략하고 `daily_stock()` 함수를 실행한 결과는 다음과 같습니다.

# %%
kq.daily_stock("005930", "20230101")
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2023-01-02  005930  55,500  56,100  55,200  55,500  10,031,448
# 1   2023-01-03  005930  55,400  56,000  54,500  55,400  13,547,030
# 2   2023-01-04  005930  55,700  58,000  55,600  57,800  20,188,071
# 3   2023-01-05  005930  58,200  58,800  57,600  58,200  15,682,826
# 4   2023-01-06  005930  58,300  59,400  57,900  59,000  17,334,989
# ..         ...     ...     ...     ...     ...     ...         ...
# 155 2023-08-17  005930  66,300  66,800  66,000  66,700  10,778,652
# 156 2023-08-18  005930  66,000  66,700  65,800  66,300  11,745,006
# 157 2023-08-21  005930  66,600  67,100  66,300  66,600   9,720,067
# 158 2023-08-22  005930  67,200  67,700  66,300  66,600  10,500,242
# 159 2023-08-23  005930  66,700  67,100  66,400  67,000   4,151,325
#
#                 AMOUNT    CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0      558,433,491,400    200   0.3600         2       00       55,500
# 1      747,898,872,200   -100  -0.1800         5       00       55,400
# 2    1,151,473,733,800  2,400   4.3300         2       00       55,700
# 3      911,973,904,900    400   0.6900         2       00       58,200
# 4    1,018,769,177,900    800   1.3700         2       00       58,300
# ..                 ...    ...      ...       ...      ...          ...
# 155    716,095,782,444   -300  -0.4500         5       00       66,300
# 156    778,550,834,100   -400  -0.6000         5       00       66,000
# 157    647,498,994,572    300   0.4500         2       00       66,600
# 158    702,152,276,000      0   0.0000         3       00       67,200
# 159    277,363,414,900    400   0.6000         2       00       66,700
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         56,100      55,200        55,500         200          0.3600
# 1         56,000      54,500        55,400        -100         -0.1800
# 2         58,000      55,600        57,800       2,400          4.3300
# 3         58,800      57,600        58,200         400          0.6900
# 4         59,400      57,900        59,000         800          1.3700
# ..           ...         ...           ...         ...             ...
# 155       66,800      66,000        66,700        -300         -0.4500
# 156       66,700      65,800        66,300        -400         -0.6000
# 157       67,100      66,300        66,600         300          0.4500
# 158       67,700      66,300        66,600           0          0.0000
# 159       67,100      66,400        67,000         400          0.6000
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 2  331,322,931,525,000  5,969,782,550
# 1                 5  330,725,953,270,000  5,969,782,550
# 2                 2  345,053,431,390,000  5,969,782,550
# 3                 2  347,441,344,410,000  5,969,782,550
# 4                 2  352,217,170,450,000  5,969,782,550
# ..              ...                  ...            ...
# 155               5  398,184,496,085,000  5,969,782,550
# 156               5  395,796,583,065,000  5,969,782,550
# 157               2  397,587,517,830,000  5,969,782,550
# 158               3  397,587,517,830,000  5,969,782,550
# 159               2  399,975,430,850,000  5,969,782,550
#
# [160 rows x 21 columns]

# %% [markdown]
# `start_date` 인수를 생략하면 `end_date` 인수값으로 지정된 날짜의 1년 전을 가정하여 정보를 출력합니다.
# `start_date` 인수와 `end_date` 인수를 모두 생략하면 함수를 호출한 날로부터 1년전부터 당일까지의 정보를 출력합니다.

# %%
kq.daily_stock("005930")
# Out:
#           DATE  SYMBOL    OPEN    HIGH     LOW   CLOSE      VOLUME  \
# 0   2022-08-23  005930  59,000  59,600  59,000  59,100   9,041,629
# 1   2022-08-24  005930  59,200  59,500  59,000  59,000   8,888,486
# 2   2022-08-25  005930  59,200  59,700  59,000  59,700   5,767,902
# 3   2022-08-26  005930  60,300  60,900  59,900  60,000   9,499,995
# 4   2022-08-29  005930  58,700  58,900  58,600  58,600   9,841,329
# ..         ...     ...     ...     ...     ...     ...         ...
# 244 2023-08-17  005930  66,300  66,800  66,000  66,700  10,778,652
# 245 2023-08-18  005930  66,000  66,700  65,800  66,300  11,745,006
# 246 2023-08-21  005930  66,600  67,100  66,300  66,600   9,720,067
# 247 2023-08-22  005930  67,200  67,700  66,300  66,600  10,500,242
# 248 2023-08-23  005930  66,700  67,100  66,400  67,000   4,151,325
#
#               AMOUNT     CHG  CHG_PCT  CHG_TYPE EX_EVENT  OPEN_NOTADJ  \
# 0    535,657,353,300    -900  -1.5000         5       00       59,000
# 1    525,406,965,200    -100  -0.1700         5       00       59,200
# 2    342,780,937,200     700   1.1900         2       00       59,200
# 3    573,040,309,950     300   0.5000         2       00       60,300
# 4    577,684,200,900  -1,400  -2.3300         5       00       58,700
# ..               ...     ...      ...       ...      ...          ...
# 244  716,095,782,444    -300  -0.4500         5       00       66,300
# 245  778,550,834,100    -400  -0.6000         5       00       66,000
# 246  647,498,994,572     300   0.4500         2       00       66,600
# 247  702,152,276,000       0   0.0000         3       00       67,200
# 248  277,363,414,900     400   0.6000         2       00       66,700
#
#      HIGH_NOTADJ  LOW_NOTADJ  CLOSE_NOTADJ  CHG_NOTADJ  CHG_PCT_NOTADJ  \
# 0         59,600      59,000        59,100        -900         -1.5000
# 1         59,500      59,000        59,000        -100         -0.1700
# 2         59,700      59,000        59,700         700          1.1900
# 3         60,900      59,900        60,000         300          0.5000
# 4         58,900      58,600        58,600      -1,400         -2.3300
# ..           ...         ...           ...         ...             ...
# 244       66,800      66,000        66,700        -300         -0.4500
# 245       66,700      65,800        66,300        -400         -0.6000
# 246       67,100      66,300        66,600         300          0.4500
# 247       67,700      66,300        66,600           0          0.0000
# 248       67,100      66,400        67,000         400          0.6000
#
#     CHG_TYPE_NOTADJ            MARKETCAP         SHARES
# 0                 5  352,814,148,705,000  5,969,782,550
# 1                 5  352,217,170,450,000  5,969,782,550
# 2                 2  356,396,018,235,000  5,969,782,550
# 3                 2  358,186,953,000,000  5,969,782,550
# 4                 5  349,829,257,430,000  5,969,782,550
# ..              ...                  ...            ...
# 244               5  398,184,496,085,000  5,969,782,550
# 245               5  395,796,583,065,000  5,969,782,550
# 246               2  397,587,517,830,000  5,969,782,550
# 247               3  397,587,517,830,000  5,969,782,550
# 248               2  399,975,430,850,000  5,969,782,550
#
# [249 rows x 21 columns]

# %% [markdown]
# ## 3.4 일중 주가정보

# %% [markdown]
# `intra_stock()` 함수는 호출 당일의 10초 또는 1분 간격 일중정보를 제공합니다.
#
# 시간 간격은 `interval` 인수의 값으로 설정하며 `"10S"`는 10초, `"10S"`는 1분 간격입니다.
# `interval` 인수의 값을 생략하면 1분으로 가정합니다.
#
# 10초 정보의 경우 거래소 상황에 따라 원 데이터 자체에 일부 데이터 누락이 있을 수 있습니다.

# %%
# 1분 간격 일중정보
kq.intra_stock("005930")
# Out:
#                DATETIME       DATE      TIME  SYMBOL    OPEN    HIGH     LOW  \
# 1   2023-08-23 09:00:00 2023-08-23  09:00:00  005930  66,700  66,700  66,600
# 2   2023-08-23 09:01:00 2023-08-23  09:01:00  005930  66,600  66,700  66,400
# 3   2023-08-23 09:02:00 2023-08-23  09:02:00  005930  66,500  66,600  66,400
# 4   2023-08-23 09:03:00 2023-08-23  09:03:00  005930  66,500  66,600  66,400
# 5   2023-08-23 09:04:00 2023-08-23  09:04:00  005930  66,500  66,500  66,400
# ..                  ...        ...       ...     ...     ...     ...     ...
# 101 2023-08-23 10:40:00 2023-08-23  10:40:00  005930  67,000  67,000  66,900
# 102 2023-08-23 10:41:00 2023-08-23  10:41:00  005930  67,000  67,000  66,900
# 103 2023-08-23 10:42:00 2023-08-23  10:42:00  005930  67,000  67,000  66,900
# 104 2023-08-23 10:43:00 2023-08-23  10:43:00  005930  66,900  67,000  66,900
# 105 2023-08-23 10:44:00 2023-08-23  10:44:00  005930  67,000  67,000  66,900
#
#       CLOSE   VOLUME          AMOUNT  VOLUME_ACC       AMOUNT_ACC   CHG  \
# 1    66,600  411,681  27,458,322,100     411,681   27,458,322,100     0
# 2    66,500  173,118  11,514,539,000     584,799   38,972,861,100  -100
# 3    66,600   30,302   2,015,709,300     615,101   40,988,570,400     0
# 4    66,500  102,871   6,841,050,200     717,972   47,829,620,600  -100
# 5    66,400   20,594   1,367,726,700     738,566   49,197,347,300  -200
# ..      ...      ...             ...         ...              ...   ...
# 101  67,000    3,928     263,014,600   4,134,587  276,242,635,200   400
# 102  67,000    3,815     255,422,900   4,138,402  276,498,058,100   400
# 103  67,000    6,073     406,733,100   4,144,475  276,904,791,200   400
# 104  67,000    5,982     400,531,200   4,150,457  277,305,322,400   400
# 105  67,000      352      23,565,700   4,150,809  277,328,888,100   400
#
#      CHG_PCT  CHG_TYPE
# 1     0.0000         3
# 2    -0.1500         5
# 3     0.0000         3
# 4    -0.1500         5
# 5    -0.3000         5
# ..       ...       ...
# 101   0.6000         2
# 102   0.6000         2
# 103   0.6000         2
# 104   0.6000         2
# 105   0.6000         2
#
# [105 rows x 15 columns]

# %%
# 10초 간격 일중정보
kq.intra_stock("005930", "10S")
# Out:
#                DATETIME       DATE      TIME  SYMBOL    OPEN    HIGH     LOW  \
# 0   2023-08-23 09:00:00 2023-08-23  09:00:00  005930  66,600  66,600  66,600
# 1   2023-08-23 09:00:30 2023-08-23  09:00:30  005930  66,700  66,700  66,600
# 2   2023-08-23 09:00:40 2023-08-23  09:00:40  005930  66,600  66,700  66,600
# 3   2023-08-23 09:00:50 2023-08-23  09:00:50  005930  66,700  66,700  66,600
# 4   2023-08-23 09:01:00 2023-08-23  09:01:00  005930  66,600  66,700  66,600
# ..                  ...        ...       ...     ...     ...     ...     ...
# 619 2023-08-23 10:43:30 2023-08-23  10:43:30  005930  67,000  67,000  66,900
# 620 2023-08-23 10:43:40 2023-08-23  10:43:40  005930  66,900  67,000  66,900
# 621 2023-08-23 10:43:50 2023-08-23  10:43:50  005930  67,000  67,000  66,900
# 622 2023-08-23 10:44:00 2023-08-23  10:44:00  005930  66,900  67,000  66,900
# 623 2023-08-23 10:44:10 2023-08-23  10:44:10  005930  67,000  67,000  66,900
#
#       CLOSE   VOLUME          AMOUNT  VOLUME_ACC       AMOUNT_ACC  CHG  \
# 0    66,600        0               0           0                0    0
# 1    66,600  317,520  21,178,294,200     317,520   21,178,294,200    0
# 2    66,700   90,618   6,043,972,600     408,138   27,222,266,800  100
# 3    66,700    2,919     194,442,100     411,057   27,416,708,900  100
# 4    66,600      624      41,613,200     411,681   27,458,322,100    0
# ..      ...      ...             ...         ...              ...  ...
# 619  67,000    1,336      89,509,600   4,147,401  277,100,758,400  400
# 620  67,000    1,018      68,134,800   4,148,419  277,168,893,200  400
# 621  67,000    1,628     108,977,200   4,150,047  277,277,870,400  400
# 622  67,000      410      27,452,000   4,150,457  277,305,322,400  400
# 623  67,000      352      23,565,700   4,150,809  277,328,888,100  400
#
#      CHG_PCT  CHG_TYPE
# 0     0.0000         0
# 1     0.0000         3
# 2     0.1500         2
# 3     0.1500         2
# 4     0.0000         3
# ..       ...       ...
# 619   0.6000         2
# 620   0.6000         2
# 621   0.6000         2
# 622   0.6000         2
# 623   0.6000         2
#
# [624 rows x 15 columns]

# %% [markdown]
# ## 3.5 전종목 주가정보 동시 조회

# %% [markdown]
# `rank_stocks` 함수는 전 종목의 주가정보를 동시에 조회하는 함수입니다.

# %%
kq.rank_stocks()
# Out:
#        SYMBOL     OPEN     HIGH      LOW    CLOSE     VOLUME           AMOUNT  \
# 0      005930   66,700   67,100   66,400   67,000  4,151,795  277,394,904,900
# 1      373220  535,000  538,000  530,000  531,000     52,216   27,839,316,000
# 2      000660  116,200  116,800  114,600  115,000    840,402   97,056,326,400
# 3      207940  766,000  777,000  763,000  765,000     12,123    9,316,686,000
# 4      005490  560,000  561,000  545,000  546,000    369,025  203,850,188,000
# ...       ...      ...      ...      ...      ...        ...              ...
# 3,754  426410   12,465   12,465   12,330   12,330         66          815,425
# 3,755  287330    5,900    5,930    5,860    5,930         14           82,355
# 3,756  315480   10,570   10,570   10,550   10,550          2           21,120
# 3,757  287320   11,920   11,950   11,920   11,950          2           23,870
# 3,758  301440        0        0        0   10,255          0                0
#
#        PREV_CLOSE  CHG_PCT  CHG_TYPE            MARKETCAP  \
# 0          66,600   0.6006         2  399,975,430,850,000
# 1         539,000  -1.4842         5  124,254,000,000,000
# 2         116,500  -1.2876         5   83,720,271,975,000
# 3         773,000  -1.0349         5   54,448,110,000,000
# 4         560,000  -2.5000         5   46,175,891,580,000
# ...           ...      ...       ...                  ...
# 3,754      12,510  -1.4388         5        1,849,500,000
# 3,755       5,855   1.2810         2        1,304,600,000
# 3,756      10,545   0.0474         2        1,266,000,000
# 3,757      11,880   0.5892         2        1,195,000,000
# 3,758      10,255   0.0000         0        1,025,500,000
#
#                                NAME                                  NAME_EN  \
# 0                          삼성전자                              SamsungElec
# 1                    LG에너지솔루션                       LG Energy Solution
# 2                        SK하이닉스                                 SK hynix
# 3                  삼성바이오로직스                        SAMSUNG BIOLOGICS
# 4                       POSCO홀딩스                           POSCO Holdings
# ...                             ...                                      ...
# 3,754   ARIRANG 미국대체투자Top10MV  ARIRANG Top10 US Listed Alt Managers MV
# 3,755          KBSTAR 200생활소비재                       KBSTAR 200 Con&Sta
# 3,756  KBSTAR 200커뮤니케이션서비스                             KBSTAR 200CS
# 3,757              KBSTAR 200산업재                   KBSTAR 200 Industrials
# 3,758          ARIRANG 코스피중형주                     ARIRANG KOSPI MidCap
#
#       SEC_TYPE    MARKET
# 0           ST  유가증권
# 1           ST  유가증권
# 2           ST  유가증권
# 3           ST  유가증권
# 4           ST  유가증권
# ...        ...       ...
# 3,754       EF  유가증권
# 3,755       EF  유가증권
# 3,756       EF  유가증권
# 3,757       EF  유가증권
# 3,758       EF  유가증권
#
# [3759 rows x 15 columns]

# %% [markdown]
# `rank_stocks` 함수는 기본적으로 시가총액 기준으로 정렬한 결과를 출력합니다. `order_key` 인수를 사용하여 다양한 기준으로 정렬할 수 있습니다.

# %%
kq.rank_stocks(order_key="VOLUME")
# Out:
#        SYMBOL   OPEN   HIGH    LOW   CLOSE      VOLUME           AMOUNT  \
# 0      277410  3,735  3,995  3,315   3,985  62,568,308  229,464,580,990
# 1      252670  2,715  2,725  2,685   2,695  53,212,551  143,662,871,720
# 2      214680  4,265  5,070  4,175   4,850  44,616,770  210,260,980,340
# 3      251340  3,580  3,650  3,580   3,645  31,739,217  114,608,597,650
# 4      267320  4,985  6,150  4,970   5,410  29,604,003  166,408,931,880
# ...       ...    ...    ...    ...     ...         ...              ...
# 3,754  530015      0      0      0  18,600           0                0
# 3,755  530016      0      0      0  15,955           0                0
# 3,756  530020      0      0      0  18,540           0                0
# 3,757  520026      0      0      0   8,415           0                0
# 3,758  114120      0      0      0  10,850           0                0
#
#        PREV_CLOSE  CHG_PCT  CHG_TYPE          MARKETCAP  \
# 0           3,480  14.5115         2    144,167,692,165
# 1           2,690   0.1859         2  1,726,147,500,000
# 2           4,160  16.5865         2    350,779,581,950
# 3           3,565   2.2440         2  1,083,658,500,000
# 4           4,890  10.6339         2    218,208,806,450
# ...           ...      ...       ...                ...
# 3,754      18,600   0.0000         0     37,200,000,000
# 3,755      15,955   0.0000         0     31,910,000,000
# 3,756      18,540   0.0000         0     37,080,000,000
# 3,757       8,415   0.0000         0    126,225,000,000
# 3,758      10,850   0.0000         0     24,913,021,350
#
#                                     NAME  \
# 0                                 인산가
# 1                  KODEX 200선물인버스2X
# 2                                 디알텍
# 3              KODEX 코스닥150선물인버스
# 4                               나인테크
# ...                                  ...
# 3,754       삼성 미국 대형 성장주 ETN(H)
# 3,755       삼성 미국 대형 가치주 ETN(H)
# 3,756          삼성 미국 대형 가치주 ETN
# 3,757  미래에셋 코스피 양매도 5% OTM ETN
# 3,758                           크루셜텍
#
#                                         NAME_EN SEC_TYPE    MARKET
# 0                                         INSAN       ST    코스닥
# 1                  KODEX 200 Futures Inverse 2X       EF  유가증권
# 2                                        DRTECH       ST    코스닥
# 3                       KODEX KOSDAQ150 INVERSE       EF  유가증권
# 4                                      Naintech       ST    코스닥
# ...                                         ...      ...       ...
# 3,754        Samsung US Large Cap Growth ETN(H)       EN  유가증권
# 3,755         Samsung US Large Cap Value ETN(H)       EN  유가증권
# 3,756            Samsung US Large Cap Value ETN       EN  유가증권
# 3,757  MiraeAsset KOSPI ShortStrangle 5%OTM ETN       EN  유가증권
# 3,758                                CrucialTec       ST    코스닥
#
# [3759 rows x 15 columns]
